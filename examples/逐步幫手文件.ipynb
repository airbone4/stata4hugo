# %% [raw]
# ---
# title: 逐步幫手文件
# description: 逐步幫手文件
# tags: []
# categories: []
# series: []
# editext: Rmarkdown
# ---

# %% [markdown]
# <!--more-->
#
# <!--more-->
#
# ```stata
# xxxxxxxxxxxxxxxxxx
# ```

# %%
library(Statamarkdown)
knitr::opts_chunk$set(cleanlog = F)

# %% [markdown]
# ## 紀錄

# %% [markdown]
# ```stata,echo=F,block.pre.class="ms-5.w-75"
# use "https://rmilab.nkust.edu.tw/files/bookdata/lecture/chen_ex_10_2.dta", clear
# sw regress y x1 x2 x3 x4,pr(0.05)
#
#
# ```
#
# ```stata
# . use "https://rmilab.nkust.edu.tw/files/bookdata/lecture/chen_ex_10_2.dta", clear
#
# . sw regress y x1 x2 x3 x4,pr(0.05)
#                       begin with full model
# p = 0.3437 >= 0.0500  removing x3
# p = 0.1795 >= 0.0500  removing x2
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(2, 29)        =   2178.07
#        Model |  929.079519         2   464.53976   Prob > F        =    0.0000
#     Residual |   6.1851209        29  .213280031   R-squared       =    0.9934
# -------------+----------------------------------   Adj R-squared   =    0.9929
#        Total |   935.26464        31  30.1698271   Root MSE        =    .46182
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x1 |   .5066342   .0119867    42.27   0.000     .4821188    .5311497
#           x4 |   .5010896   .0095479    52.48   0.000     .4815619    .5206173
#        _cons |  -5.110359    .378407   -13.50   0.000    -5.884289    -4.33643
# ------------------------------------------------------------------------------
#
# .
# .
#
#
# ```

# %% [markdown]
# ```stata,echo=F,block.pre.class="ms-5.w-75"
# use "https://rmilab.nkust.edu.tw/files/bookdata/lecture/chen_ex_10_2.dta", clear
# sw reg y x1-x4 , pe(0.99) pr(0.999) forward
# reg y x1
# reg y x2
# reg y x3
# reg y x4
# //x2 被選,因為F最大(紅字)
# reg y x2 x1
# reg y x2 x3
# reg y x2 x4
# // adding x4 (F最大，見紅圈）
# // 然後對目前的兩個變數(x2,x4)塞選,兩個變數的p值,不用被移出因為沒有大於0.999
# reg y x2 x4 x1
#
#
#
# ```
#
# ```stata
# . use "https://rmilab.nkust.edu.tw/files/bookdata/lecture/chen_ex_10_2.dta", clear
#
# . sw reg y x1-x4 , pe(0.99) pr(0.999) forward
#                       begin with empty model
# p = 0.0000 <  0.9900  adding   x2
# p = 0.1169 <  0.9900  adding   x4
# p = 0.0000 <  0.9900  adding   x1
# p = 0.3437 <  0.9900  adding   x3
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(4, 27)        =   1120.53
#        Model |  929.664422         4  232.416106   Prob > F        =    0.0000
#     Residual |  5.60021803        27  .207415483   R-squared       =    0.9940
# -------------+----------------------------------   Adj R-squared   =    0.9931
#        Total |   935.26464        31  30.1698271   Root MSE        =    .45543
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x2 |   .1785982   .1314174     1.36   0.185    -.0910481    .4482445
#           x4 |   .4674274   .0258027    18.12   0.000     .4144846    .5203701
#           x1 |   .4720687   .0264709    17.83   0.000     .4177548    .5263826
#           x3 |   .0089598   .0092956     0.96   0.344    -.0101132    .0280329
#        _cons |  -5.444871   .4235461   -12.86   0.000    -6.313916   -4.575827
# ------------------------------------------------------------------------------
#
# . reg y x1
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(1, 30)        =     17.27
#        Model |  341.642551         1  341.642551   Prob > F        =    0.0002
#     Residual |  593.622089        30   19.787403   R-squared       =    0.3653
# -------------+----------------------------------   Adj R-squared   =    0.3441
#        Total |   935.26464        31  30.1698271   Root MSE        =    4.4483
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x1 |   .4792902   .1153472     4.16   0.000     .2437198    .7148606
#        _cons |   8.262734   2.694582     3.07   0.005     2.759664    13.76581
# ------------------------------------------------------------------------------
#
# . reg y x2
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(1, 30)        =    323.44
#        Model |  855.878912         1  855.878912   Prob > F        =    0.0000
#     Residual |  79.3857284        30  2.64619095   R-squared       =    0.9151
# -------------+----------------------------------   Adj R-squared   =    0.9123
#        Total |   935.26464        31  30.1698271   Root MSE        =    1.6267
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x2 |   2.537959   .1411201    17.98   0.000     2.249753    2.826164
#        _cons |  -5.931843   1.414285    -4.19   0.000    -8.820198   -3.043488
# ------------------------------------------------------------------------------
#
# . reg y x3
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(1, 30)        =      1.64
#        Model |  48.5376834         1  48.5376834   Prob > F        =    0.2098
#     Residual |  886.726957        30  29.5575652   R-squared       =    0.0519
# -------------+----------------------------------   Adj R-squared   =    0.0203
#        Total |   935.26464        31  30.1698271   Root MSE        =    5.4367
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x3 |   .1381413   .1077999     1.28   0.210    -.0820155    .3582982
#        _cons |   15.70829   2.722082     5.77   0.000     10.14905    21.26752
# ------------------------------------------------------------------------------
#
# . reg y x4
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(1, 30)        =     42.46
#        Model |  548.064063         1  548.064063   Prob > F        =    0.0000
#     Residual |  387.200577        30  12.9066859   R-squared       =    0.5860
# -------------+----------------------------------   Adj R-squared   =    0.5722
#        Total |   935.26464        31  30.1698271   Root MSE        =    3.5926
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x4 |   .4835482   .0742047     6.52   0.000     .3320019    .6350944
#        _cons |   6.656507   1.993755     3.34   0.002     2.584716     10.7283
# ------------------------------------------------------------------------------
#
# . //x2 被選,因為F最大(紅字)
# . reg y x2 x1
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(2, 29)        =    168.53
#        Model |  861.172405         2  430.586203   Prob > F        =    0.0000
#     Residual |  74.0922345        29  2.55490464   R-squared       =    0.9208
# -------------+----------------------------------   Adj R-squared   =    0.9153
#        Total |   935.26464        31  30.1698271   Root MSE        =    1.5984
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x2 |   2.400561   .1683429    14.26   0.000     2.056261    2.744861
#           x1 |   .0724291   .0503187     1.44   0.161    -.0304841    .1753423
#        _cons |   -6.20197    1.40229    -4.42   0.000    -9.069976   -3.333964
# ------------------------------------------------------------------------------
#
# . reg y x2 x3
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(2, 29)        =    158.13
#        Model |  856.707408         2  428.353704   Prob > F        =    0.0000
#     Residual |   78.557232        29  2.70887007   R-squared       =    0.9160
# -------------+----------------------------------   Adj R-squared   =    0.9102
#        Total |   935.26464        31  30.1698271   Root MSE        =    1.6459
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x2 |   2.521192    .145965    17.27   0.000      2.22266    2.819724
#           x3 |   .0184504   .0333622     0.55   0.584    -.0497829    .0866837
#        _cons |   -6.20321   1.512731    -4.10   0.000    -9.297091   -3.109328
# ------------------------------------------------------------------------------
#
# . reg y x2 x4
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(2, 29)        =    171.71
#        Model |  862.436126         2  431.218063   Prob > F        =    0.0000
#     Residual |  72.8285145        29  2.51132808   R-squared       =    0.9221
# -------------+----------------------------------   Adj R-squared   =    0.9168
#        Total |   935.26464        31  30.1698271   Root MSE        =    1.5847
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x2 |   2.292462   .2048952    11.19   0.000     1.873404     2.71152
#           x4 |   .0788289    .048784     1.62   0.117    -.0209456    .1786034
#        _cons |   -5.53058   1.399974    -3.95   0.000    -8.393848   -2.667311
# ------------------------------------------------------------------------------
#
# . // adding x4 (F最大，見紅圈）
# . // 然後對目前的兩個變數(x2,x4)塞選,兩個變數的p值,不用被移出因為沒有大於0.999
# . reg y x2 x4 x1
#
#       Source |       SS           df       MS      Number of obs   =        32
# -------------+----------------------------------   F(3, 28)        =   1497.53
#        Model |  929.471722         3  309.823907   Prob > F        =    0.0000
#     Residual |  5.79291826        28  .206889938   R-squared       =    0.9938
# -------------+----------------------------------   Adj R-squared   =    0.9931
#        Total |   935.26464        31  30.1698271   Root MSE        =    .45485
#
# ------------------------------------------------------------------------------
#            y | Coefficient  Std. err.      t    P>|t|     [95% conf. interval]
# -------------+----------------------------------------------------------------
#           x2 |   .1806877    .131233     1.38   0.179    -.0881309    .4495062
#           x4 |   .4680677   .0257614    18.17   0.000     .4152977    .5208376
#           x1 |   .4742083   .0263443    18.00   0.000     .4202445     .528172
#        _cons |  -5.317812   .4019997   -13.23   0.000    -6.141271   -4.494353
# ------------------------------------------------------------------------------
#
# .
# .
# .
#
#
# ```
#
# ## to improve
#
# ```stata
# clear all
# //方案1
# matrix C =( 1,	-0.0136,	0.031,	0.0377,	0.6454 \ -0.0136,	1,	0.0025,	0.0018,	0.4273 \0.031,	0.0025,	1,	0.02,	-0.1768 \ 0.0377,	0.0018,	0.02,	1,	0.0083 \ 0.6454,	0.4273,	-0.1768,	0.0083,	1)
#
# matrix list C
# corr2data x1 x2 x3 x4 y, means(0 0 0 0 4) corr(C) n(1000) seed(17)
#
# //方案2
# //gen y=2+1.2*x1 +0.8*x2 -0.4*x3 -0.3*x1*x2 +rnormal()
#
# sw regress y x1 x2 x3 x4, pe(0.99) pr(0.999) forward
# //sw regress y x1 x2 x3 x4, pe(0.05) pr(0.055) forward
# ```
